# %%
import take_pic
reload(take_pic)
import cv2
tp=take_pic.TakePicture()

# %%
des = 'data/board/board_new1/'

# %%
#=========================
des = "data/board/board_calib0/test0.jpg"
start = tp.time.time()
tp.save_pic_jpg_timed(0.9,150,des)
end = tp.time.time()
print (end-start)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-3-7b8942a42920> in <module>()
#       2 des = "data/board/board_calib0/test0.jpg"
#       3 start = tp.time.time()
# ----> 4 tp.save_pic_jpg_timed(0.9,150,des)
#       5 end = tp.time.time()
#       6 print (end-start)
#
# /home/robohub/ws/src/uw_robothon/take_pic.pyc in save_pic_jpg_timed(self, sleep_time, num_img, dir)
#      40     def save_pic_jpg_timed(self,sleep_time,num_img,dir):
#      41         for i in range(num_img):
# ---> 42             img = self.take_pic_rgb()
#      43             des = dir + 'img' + str(i) + '.jpg'
#      44             img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#
# /home/robohub/ws/src/uw_robothon/take_pic.pyc in take_pic_rgb(self)
#      22
#      23     def take_pic_rgb(self):
# ---> 24         img_rgb = rospy.wait_for_message("/camera/color/image_raw",Image)
#      25         cv_image_rgb = self.bridge.imgmsg_to_cv2(img_rgb, desired_encoding='passthrough')
# ...

# %%
img = tp.take_pic_rgb()

# %%
des = "data/board/board_calib0/test1.jpg"

cv2.imwrite(des,img)

# %%
loaded_img = cv2.imread(des)
tp.show_pic(loaded_img)

# %%
import pickle
import time
from matplotlib.pyplot import figure
import matplotlib.pylab as plt

j = 0

for i in range(10):
    filename = "data/screen/img_" + str(j) + ".pickle"
    print (filename)
    cv_image_loaded_rgb = pickle.load(open(filename,"rb"))
    figure(figsize=(5,5), dpi=80)
    plt.imshow(cv_image_loaded_rgb)
    time.sleep(0.001)
    j += 1
# Out:
# data/screen/img_0.pickle
# data/screen/img_1.pickle
# data/screen/img_2.pickle
# data/screen/img_3.pickle
# data/screen/img_4.pickle
# data/screen/img_5.pickle
# data/screen/img_6.pickle
# data/screen/img_7.pickle
# data/screen/img_8.pickle
# data/screen/img_9.pickle

# %%
from matplotlib.pyplot import figure
import matplotlib.pylab as plt
import cv2
import numpy as np;
import time

# Setup SimpleBlobDetector parameters.
params = cv2.SimpleBlobDetector_Params()

params.filterByColor = False

# Change thresholds
params.minThreshold = 0;
params.maxThreshold = 255;
params.thresholdStep = 10;
 
# Filter by Area.
params.filterByArea = True
params.minArea = 5
 
# Filter by Circularity
params.filterByCircularity = False
params.minCircularity = 0.1
 
# Filter by Convexity
params.filterByConvexity = False
params.minConvexity = 0.87
 
# Filter by Inertia
params.filterByInertia = False
params.minInertiaRatio = 0.01

# Read image

#raw_img_rgb = cv2.imread("data/screen/screen1/test0.jpg") #BGR
#raw_img_bgr = cv2.cvtColor(raw_img_rgb, cv2.COLOR_RGB2BGR)

raw_img_bgr = tp.take_pic_rgb()
crop_img_bgr = raw_img_bgr[650:700,830:1100]

hsv = cv2.cvtColor(crop_img_bgr, cv2.COLOR_BGR2HSV) #HSV



#img = tp.take_pic_rgb()
#im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

# Threshold of blue in HSV space

# HSV for cv2: [0-179,0-255,0-255]

lower_blue = np.array([30, 0, 0])
upper_blue = np.array([100, 255, 255])
mask_no_blue = cv2.inRange(hsv, lower_blue, upper_blue)
img_no_blue = cv2.bitwise_and(crop_img_bgr, crop_img_bgr, mask = mask_no_blue)



lower_green = np.array([45, 0, 0])
upper_green = np.array([70, 255, 255])
mask_green = cv2.inRange(hsv, lower_green, upper_green)
img_green = cv2.bitwise_and(crop_img_bgr, crop_img_bgr, mask = mask_green)



lower_yellow = np.array([30, 0, 0])
upper_yellow = np.array([180, 255, 255])
#mask = cv2.inRange(hsv, lower_yellow, upper_yellow)


#lower_blue = np.array([0, 70, 0])
#upper_blue = np.array([160, 255, 255])



img = cv2.bitwise_and(img, img, mask = mask)
 
# Set up the detector with default parameters.
detector = cv2.SimpleBlobDetector_create(params)
 
# Detect blobs.
keypoints = detector.detect(img)
 
# Draw detected blobs as red circles.
# cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS ensures the size of the circle corresponds to the size of blob
img_with_keypoints = cv2.drawKeypoints(img, keypoints, np.array([]), (0,0,255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
 
# Show 


    
plt.imshow(img_no_blue)
#plt.imshow(img_no_blue)
time.sleep(0.1)
#plt.imshow(raw_img_rgb)
#plt.imshow(no_sky)

# %%
from matplotlib.pyplot import figure
import matplotlib.pylab as plt
import cv2
import numpy as np
import time

# Setup SimpleBlobDetector parameters.
params = cv2.SimpleBlobDetector_Params()

params.filterByColor = False

# Change thresholds
params.minThreshold = 0;
params.maxThreshold = 255;
params.thresholdStep = 1;
 
# Filter by Area.
params.filterByArea = True
params.minArea = 50
 
# Filter by Circularity
params.filterByCircularity = False
params.minCircularity = 0.1
 
# Filter by Convexity
params.filterByConvexity = False
params.minConvexity = 0.87
 
# Filter by Inertia
params.filterByInertia = False
params.minInertiaRatio = 0.01

# Read image

#raw_img_rgb = cv2.imread("data/screen/screen1/test0.jpg") #BGR
#raw_img_bgr = cv2.cvtColor(raw_img_rgb, cv2.COLOR_RGB2BGR)

raw_img_bgr = tp.take_pic_rgb()
crop_img_bgr = raw_img_bgr[650:700,830:1100]

hsv = cv2.cvtColor(crop_img_bgr, cv2.COLOR_BGR2HSV) #HSV



#img = tp.take_pic_rgb()
#im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)

# Threshold of blue in HSV space

# HSV for cv2: [0-179,0-255,0-255]

#lower_blue = np.array([30, 0, 0])
#upper_blue = np.array([100, 255, 255])
#mask_no_blue = cv2.inRange(hsv, lower_blue, upper_blue)
#img_no_blue = cv2.bitwise_and(crop_img_bgr, crop_img_bgr, mask = mask_no_blue)

lower_green = np.array([31, 100, 0])
upper_green = np.array([120, 255, 255])
mask_green = cv2.inRange(hsv, lower_green, upper_green)
img_green = cv2.bitwise_and(crop_img_bgr, crop_img_bgr, mask = mask_green)

 
# Set up the detector with default parameters.
detector = cv2.SimpleBlobDetector_create(params)
 
# Detect blobs.
keypoints = detector.detect(img_green)
 
# Draw detected blobs as red circles.
# cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS ensures the size of the circle corresponds to the size of blob
img_with_keypoints = cv2.drawKeypoints(img_green, keypoints, np.array([]), (255,0,0), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)


    
plt.imshow(img_with_keypoints)

# %%
cv2.imwrite("data/screen/screen1/test1.jpg",cv2.cvtColor(img_no_blue,cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
for point in keypoints:
    print(point.pt[0])
# Out:
# 205.255477905

# %%
dist = (137-keypoints[0].pt[0])/10000
print(dist)
# Out:
# -0.00682554779053

# %%
import os
#import pandas as pd
import sys
import pickle
import numpy as np

# fill in the directory path of the pickle files and image files
pickle_directory = 'data/screen'
image_directory = pickle_directory + '/image'

if not os.path.exists(image_directory):
    os.makedirs(image_directory)

for filename in os.listdir(pickle_directory):
    pickle_file = os.path.join(pickle_directory, filename)
    image_file = os.path.join(image_directory, filename[:-7]+".jpg")
    if os.path.isfile(pickle_file) and filename[0]!=".":
        data = open(pickle_file).read().replace('\r\n', '\n')
        dst = pickle_file + ".tmp"
        open(dst, "w").write(data) # save a temporary file
        obj = pickle.load(open(dst, "rb"))
        os.remove(dst)
        obj = cv2.cvtColor(obj, cv2.COLOR_BGR2RGB)
        cv2.imwrite(image_file,obj)
# Out:
# IndexErrorTraceback (most recent call last)
# <ipython-input-18-4cfd763e5d62> in <module>()
#      19         dst = pickle_file + ".tmp"
#      20         open(dst, "w").write(data) # save a temporary file
# ---> 21         obj = pickle.load(open(dst, "rb"))
#      22         os.remove(dst)
#      23         obj = cv2.cvtColor(obj, cv2.COLOR_BGR2RGB)
#
# /usr/lib/python2.7/pickle.pyc in load(file)
#    1382
#    1383 def load(file):
# -> 1384     return Unpickler(file).load()
#    1385
#    1386 def loads(str):
#
# /usr/lib/python2.7/pickle.pyc in load(self)
#     862             while 1:
#     863                 key = read(1)
# --> 864                 dispatch[key](self)
#     865         except _Stop, stopinst:
#     866             return stopinst.value
#
# /usr/lib/python2.7/pickle.pyc in load_pop(self)
#    1142
#    1143     def load_pop(self):
# -> 1144         del self.stack[-1]
#    1145     dispatch[POP] = load_pop
#    1146
#
# ...

# %%
plt.imshow(mask)

# %%
plt.imshow(crop_img_bgr)

# %%
for x in keypoints:
    print(x.pt)
# Out:
# (161.26332092285156, 24.695005416870117)
# (116.2680892944336, 22.939828872680664)

# %%
tp.get_slider_dist()
# Out:
# 1
# -0.011360594436645508

# %%
import rospy
from dynamic_reconfigure.srv import Reconfigure
roi = rospy.ServiceProxy("/camera/rgb_camera/auto_exposure_roi/set_parameters",Reconfigure)

# %%
from dynamic_reconfigure.msg import Config, IntParameter
c = Config()

c.ints = [
    IntParameter(name="left",value=650),
    IntParameter(name="right",value=700),
    IntParameter(name="top",value=830),
    IntParameter(name="bottom",value=1100)]
#c.groups = [{'name': "Default"}]
c = roi(c)
print(c.config)
# Out:
# bools: []
# ints:
#   -
#     name: "left"
#     value: 650
#   -
#     name: "right"
#     value: 700
#   -
#     name: "top"
#     value: 830
#   -
#     name: "bottom"
#     value: 1100
# strs: []
# doubles: []
# groups:
#   -
#     name: "Default"
#     state: True
#     id: 0
#     parent: 0

# %%
import rospy
from dynamic_reconfigure.srv import Reconfigure
camera_reconfig = rospy.ServiceProxy("/camera/rgb_camera/set_parameters",Reconfigure)
from dynamic_reconfigure.msg import Config, IntParameter, BoolParameter
c = Config()
c.ints = [IntParameter(name="exposure",value=180)]
c.bools = [BoolParameter(name="enable_auto_exposure",value=False)]
c = camera_reconfig(c)

# %%
img = tp.take_pic_rgb()
import cv2
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
orb = cv2.ORB_create()
kp = orb.detect(gray,None)
kp, des = orb.compute(gray, kp)
img_out = cv2.drawKeypoints(gray, kp, None, color=(0,255,0), flags=0)
import matplotlib.pylab as plt
plt.imshow(img_out)

# %%
img2 = tp.take_pic_rgb()
import cv2
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
orb2 = cv2.ORB_create()
kp2 = orb.detect(gray2,None)
kp2, des2 = orb.compute(gray2, kp2)
img_out2 = cv2.drawKeypoints(gray2, kp2, None, color=(0,255,0), flags=0)
import matplotlib.pylab as plt
plt.imshow(img_out2)

# %%
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks = 50)
flann = cv2.FlannBasedMatcher(index_params, search_params)
import numpy
matches = flann.knnMatch(
    numpy.asarray(des,numpy.float32),
    numpy.asarray(des2,numpy.float32),
    k=2)
# store all the good matches as per Lowe's ratio test.
good = []
for m,n in matches:
    if m.distance < 0.7*n.distance:
        good.append(m)

#cv2.findHomography(kp,kp2,cv2.RANSAC, 5.0)

# %%
MIN_MATCH_COUNT = 10
print(len(good))
if len(good)>MIN_MATCH_COUNT:
    src_pts = numpy.float32([ kp[m.queryIdx].pt for m in good ]).reshape(-1,1,2)
    dst_pts = numpy.float32([ kp2[m.trainIdx].pt for m in good ]).reshape(-1,1,2)
    M, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC,5.0)
    matchesMask = mask.ravel().tolist()
    h,w = gray.shape
    pts = numpy.float32([ [0,0],[0,h-1],[w-1,h-1],[w-1,0] ]).reshape(-1,1,2)
    dst = cv2.perspectiveTransform(pts,M)
    res = cv2.polylines(gray2,[numpy.int32(dst)],True,255,3, cv2.LINE_AA)
    plt.imshow(res)
else:
    print( "Not enough matches are found - {}/{}".format(len(good), MIN_MATCH_COUNT) )
    matchesMask = None
# Out:
# 23

# %%
print(M)
draw_params = dict(matchColor = (0,255,0), # draw matches in green color
                   singlePointColor = None,
                   matchesMask = matchesMask, # draw only inliers
                   flags = 2)
img3 = cv2.drawMatches(gray,kp,gray2,kp2,good,None,**draw_params)
plt.imshow(img3, 'gray')
# Out:
# [[  1.22787089e+00   6.50507505e-02  -2.70431144e+02]
#  [  5.79017356e-02   1.18980430e+00  -6.53036715e+01]
#  [  8.14128460e-05   1.23603202e-04   1.00000000e+00]]

# %%
import rospy
from sensor_msgs.msg import CameraInfo, Image
msg = rospy.wait_for_message("/camera/color/camera_info",CameraInfo)
camera_info_K = numpy.array(msg.K).reshape([3, 3])
camera_info_D = numpy.array(msg.D)
print(camera_info_K)
# Out:
# [[  1.38531897e+03   0.00000000e+00   9.82503296e+02]
#  [  0.00000000e+00   1.38535498e+03   5.37843567e+02]
#  [  0.00000000e+00   0.00000000e+00   1.00000000e+00]]

# %%
fx = camera_info_K[0,0]
fy = camera_info_K[1,1]
cx = camera_info_K[0,2]
cy = camera_info_K[1,2]
z = 200
object_points = numpy.array([
    [(x.pt[0]-cx*z)/fx,(x.pt[1]-cy*z)/fy,z] for x in kp2])
object_points
# Out:
# array([[-140.6778247 ,  -77.21971256,  200.        ],
#        [-140.93552709,  -77.25363888,  200.        ],
#        [-141.38163373,  -76.90066076,  200.        ],
#        ...,
#        [-141.30189166,  -77.34700909,  200.        ],
#        [-141.09496857,  -77.30045261,  200.        ],
#        [-140.99668001,  -77.33407674,  200.        ]])

# %%
image_points = numpy.array([x.pt for x in kp2])
retval, rvec, tvec= cv2.solvePnP(object_points,image_points,camera_info_K,camera_info_D)
print(retval)
print(rvec)
print(tvec)
print(len(kp2))
print(len(inliers))
# Out:
# True
# [[  6.03641859e-13]
#  [ -7.67323181e-13]
#  [  1.73892609e-13]]
# [[ 141.13583958]
#  [  77.25880465]
#  [-199.        ]]
# 500
# 500

# %%
help(cv2.solvePnPRansac)
# Out:
# Help on built-in function solvePnPRansac:
#
# solvePnPRansac(...)
#     solvePnPRansac(objectPoints, imagePoints, cameraMatrix, distCoeffs[, rvec[, tvec[, useExtrinsicGuess[, iterationsCount[, reprojectionError[, confidence[, inliers[, flags]]]]]]]]) -> retval, rvec, tvec, inliers

# %%
import copy
pts_new = copy.deepcopy(pts)
print(pts)
print(numpy.zeros((pts_new.shape[1],1)).shape)
numpy.hstack([pts_new,numpy.zeros((pts_new.shape[0],1))])
# Out:
# [[[    0.     0.]]
#
#  [[    0.  1079.]]
#
#  [[ 1919.  1079.]]
#
#  [[ 1919.     0.]]]
# (1, 1)
# ValueErrorTraceback (most recent call last)
# <ipython-input-141-3d15a58520dc> in <module>()
#       3 print(pts)
#       4 print(numpy.zeros((pts_new.shape[1],1)).shape)
# ----> 5 numpy.hstack([pts_new,numpy.zeros((pts_new.shape[0],1))])
#
# /usr/lib/python2.7/dist-packages/numpy/core/shape_base.pyc in hstack(tup)
#     291         return _nx.concatenate(arrs, 0)
#     292     else:
# --> 293         return _nx.concatenate(arrs, 1)
#     294
#     295
#
# ValueError: all the input arrays must have same number of dimensions
